# %% [markdown]
# ### Meu primeiro programa, bora pra cima Hashtag.

# %%
print('Olá, mundo!')
print('Meu primeiro código!')
# Out:
# Olá, mundo!
# Meu primeiro código!
# Teste GitHub
# Teste GitHub
# Teste GitHub
